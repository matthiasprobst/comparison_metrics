# %% [markdown]
# # From Oberkampf

# %%
import numpy as np

# %%
from comparson_metrics import cmp_xarray
import comparson_metrics as cmp

# %%
s1, s2 = cmp.tutorial.load_dataset('1d_signals')  # returns two xarray Data Array objects
s1
# Out:
# <xarray.DataArray (x: 11)>
# array([0.        , 0.29552021, 0.56464247, 0.78332691, 0.93203909,
#        0.99749499, 0.97384763, 0.86320937, 0.67546318, 0.42737988,
#        0.14112001])
# Coordinates:
#   * x        (x) float64 0.0 0.3 0.6 0.9 1.2 1.5 1.8 2.1 2.4 2.7 3.0
# Attributes:
#     units:      au
#     long_name:  signal 1

# %%
s2[4] = 1.3

# %%
s2.plot()

# %%
from comparson_metrics.core import Comparison

# %%
cmp = Comparison(s1, s2)

# %% [markdown]
# Assuming zero experimental measurement error:

# %%
def equation16(y, Y):
    N = len(y)
    return 1-np.mean(np.tanh(np.abs((y-Y)/Y)))

# %%
r = equation16(cmp.o, cmp.o)

# %%
r
# Out:
# <xarray.DataArray ()>
# array(1.)

# %%
y=cmp.o
Y=cmp.p
v = np.tanh(np.abs((y-Y)/Y))
v.plot()

# %% [markdown]
# equation 22:

# %%
from scipy import stats

# %%
def equation_23(Y, Ymean):
    N = len(Y)
    return 1/(N-1)*np.sum((Y-Ymean)**2)

# %%
s = np.linspace(0, 1, 10)

# %%
np.std(s)
# Out:
# 0.31914236925211265

# %%
equation_23(s, np.mean(s))
# Out:
# 0.11316872427983538

# %%
def equation_24(nu

# %%
stats.t.stats(2.75, moments='mv')
# Out:
# (array(0.), array(3.66666667))
